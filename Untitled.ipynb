# %%
import pandas as pd

# %%
csvFile =pd.read_csv('Salaries.csv')

# %%
csvFile.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df=pd.DataFrame(csvFile)

# %%
df
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
maxOvertime=df.groupby('OvertimePay')

# %%
maxOvertime.max()
# Out:
#                   Id              EmployeeName  \
# OvertimePay
# -0.01          90715         Claudia M Sanchez
# 0.0           131071                Zuri Jones
# 0.02           44426         Leonid Vaynshteyn
# 0.52           99025           Pamela J Walker
# 0.77           33722             JANIEN BISHOP
# 1.34           34987            EDNALYN MARTIN
# 1.76           82109                  Leo  Lam
# 2.87           30319            IRIS BIBLOWITZ
# 3.16            7235              MATHEW FLUKE
# 3.19          105115           Ingrid D Ayerdi
# 3.38            7407              BECKI NEWMAN
# 3.45            7021            KEVIN O'ROURKE
# 3.48           30447              MISTY PATTON
# 3.5            43911            Romeo Delavega
# 3.54           72208             Eric Williams
# 3.57          117682            MARGARET PRICE
# 3.58           79669       Jessie A Washington
# 3.78            8012                NIKO SHARK
# 4.18           98450   Patricia  Alvarez-Perez
# ...

# %%
avgBaseSalary=max(df['BasePay'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-f5f23f80e2e4> in <module>
# ----> 1 avgBaseSalary=max(df['BasePay'])
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %%
df['BasePay'].avg
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-39ae8d93be19> in <module>
# ----> 1 df['BasePay'].avg
#
# ~\anaconda3\envs\nlp_course\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'avg'

# %%
df[]
